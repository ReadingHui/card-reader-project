# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import os
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split, Dataset
from torch.utils.data.dataset import Subset
import matplotlib.pyplot as plt

RANDOM_STATE = 1048576
# Device configuration (use GPU if available, else CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# # Minimal Working Example

# %% [markdown]
# # Data Import

# %%
def import_data(root: str, verbose: bool=False) -> datasets.ImageFolder:
    # Load the entire dataset from a single directory
    full_dataset = datasets.ImageFolder(root=root, transform=None)

    # Print the total number of images and class names if verbose=True
    if verbose:
        print(f"Total number of images: {len(full_dataset)}")
        print(f"Number of classes: {len(full_dataset.classes)}")
        print(f"First 5 Classes: {full_dataset.classes[:5]}")
    return full_dataset

full_dataset = import_data('dataset', verbose=True)
# Out:
# Total number of images: 18875
# Number of classes: 165
# First 5 Classes: ['base1', 'base2', 'base3', 'base4', 'base5']

# %% [markdown]
# # Image Transformation

# %%
from torchvision.transforms import RandomApply, RandomAffine, RandomPerspective, RandomErasing, GaussianBlur, ColorJitter

# Define a set of augmentations for training
train_transform = transforms.Compose([
    transforms.Resize((342, 245)),  # Resize to a fixed size (adjust based on your model input)
    RandomApply([ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.05)], p=0.5),  # Random lighting variations
    RandomApply([GaussianBlur(kernel_size=(5, 5), sigma=(0.1, 2.0))], p=0.3),  # Simulate out-of-focus
    RandomAffine(degrees=(-10, 10), translate=(0.1, 0.1), scale=(0.9, 1.1)),  # Simulate different angles with rotation and scaling
    RandomPerspective(distortion_scale=0.2, p=0.3),  # Simulate perspective changes
    transforms.RandomHorizontalFlip(p=0.5),  # Randomly flip images horizontally
    transforms.ToTensor(),  # Convert image to tensor
    RandomErasing(p=0.2, scale=(0.02, 0.2), ratio=(0.3, 3.3)),  # Simulate partial occlusion
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),  # Normalize with ImageNet stats (adjust if needed)
])

# Define a simpler transform for validation/test (no augmentation)
val_transform = transforms.Compose([
    transforms.Resize((342, 245)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %% [markdown]
# # Train-val-test Split

# %%
class TransformSubset(Dataset):
    def __init__(self, subset, transform=None):
        self.subset = subset
        self.transform = transform

    def __getitem__(self, idx):
        img, label = self.subset[idx]
        if self.transform:
            img = self.transform(img)
        return img, label

    def __len__(self):
        return len(self.subset)

# %%
def train_test_split(data: datasets.ImageFolder, val_ratio: float=0.1, test_ratio: float=0.1, batch_size: int=32, train_transform: transforms=None, val_transform: transforms=None, random_state=RANDOM_STATE, verbose: bool=False) -> tuple:
    torch.manual_seed(random_state)

    test_size = int(test_ratio * len(data))
    val_size = int(val_ratio * len(data))
    train_size = len(data) - test_size - val_size

    train_subset, val_subset, test_subset = random_split(data, [train_size, val_size, test_size])

    # Wrap with independent transforms
    train_dataset = TransformSubset(train_subset, transform=train_transform)
    val_dataset = TransformSubset(val_subset, transform=val_transform)
    test_dataset = TransformSubset(test_subset, transform=val_transform)

    if verbose:
        print(f"Training set size: {len(train_dataset)}")
        print(f"Validation set size: {len(val_dataset)}")
        print(f"Test set size: {len(test_dataset)}")

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=0)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=0)

    return train_loader, val_loader, test_loader

train_loader, val_loader, test_loader = train_test_split(full_dataset, batch_size=32, train_transform=train_transform, val_transform=val_transform, random_state=RANDOM_STATE, verbose=True)
# Out:
# Training set size: 15101
# Validation set size: 1887
# Test set size: 1887

# %% [markdown]
# # Visualize the transformations (only works when num_workers=0)

# %%
import matplotlib.pyplot as plt

def visualize_augmentations(data_loader, num_samples=5, save_path=None):
    # Grab one batch
    images, labels = next(iter(data_loader))
    
    # Ensure we don't exceed batch size
    num_samples = min(num_samples, len(images))

    class_names = data_loader.dataset.subset.dataset.classes

    fig, axes = plt.subplots(1, num_samples, figsize=(4 * num_samples, 4))
    if num_samples == 1:
        axes = [axes]

    for i in range(num_samples):
        img = images[i].permute(1, 2, 0).numpy()
        img = np.clip(img, 0, 1)  # Clip to [0, 1] for display
        label = labels[i].item()
        axes[i].imshow(img)
        axes[i].set_title(f"Class: {class_names[label]}")
        axes[i].axis("off")

    plt.tight_layout()
    plt.show()

# Example usage
visualize_augmentations(train_loader, num_samples=5)

# %% [markdown]
# # Model Building

# %%
# Define a ConvBlock class that groups Conv2d, ReLU, and MaxPool2d
class ConvBlock(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3, stride=1, padding=1, pool_size=2, pool_stride=2):
        super(ConvBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding)
        self.conv2 = nn.Conv2d(out_channels, out_channels, kernel_size=kernel_size, stride=stride, padding=padding)
        self.relu1 = nn.ReLU()
        self.relu2 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(out_channels)
        self.bn2 = nn.BatchNorm2d(out_channels)
        self.pool = nn.MaxPool2d(kernel_size=pool_size, stride=pool_stride)
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)  # Apply BatchNorm before ReLU
        x = self.relu1(x)
        x = self.conv2(x)
        x = self.bn2(x)  # Apply BatchNorm before ReLU
        x = self.relu2(x)
        x = self.pool(x)
        return x

# %%
# Define the CNN model using multiple ConvBlock layers
class CardAttributeCNN(nn.Module):
    def __init__(self, num_classes):
        super(CardAttributeCNN, self).__init__()
        # Stack 3 ConvBlock layers with increasing channels
        self.block1 = ConvBlock(in_channels=3, out_channels=32)  # Input: 3 (RGB), Output: 32
        self.block2 = ConvBlock(in_channels=32, out_channels=64) # Output: 64
        self.block3 = ConvBlock(in_channels=64, out_channels=128) # Output: 128
        self.block4 = ConvBlock(in_channels=128, out_channels=256) # Output: 256
        # Fully connected layers
        # self.fc1 = nn.Linear(64 * 42 * 30, 128)  # Adjust based on final spatial dimensions after pooling
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(256, num_classes)    # Output size = number of classes
        self.dropout = nn.Dropout(0.2)  # Dropout layer for regularization
        self.global_avg_pool = nn.AdaptiveAvgPool2d(1)  # Global average pooling layer
        # Initialize weights for Conv layers
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x, return_activations=False):
        activations = []
        x = self.block1(x)
        activations.append(x)  # Store activation after block1
        x = self.block2(x)
        activations.append(x)  # Store activation after block2
        x = self.block3(x)
        activations.append(x)  # Store activation after block3
        x = self.block4(x)
        activations.append(x)
        x = self.global_avg_pool(x)
        x = torch.flatten(x, 1)
        x = self.dropout(x)
        x = self.fc2(x)
        if return_activations:
            return x, activations
        return x

# %% [markdown]
# # Model Training

# %%
checkpoint_dir = "./checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)

def save_checkpoint(model, optimizer, scheduler, epoch, loss, filename="checkpoint.pth"):
    torch.save({
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'scheduler_state_dict': scheduler.state_dict(),
        'loss': loss,
    }, os.path.join(checkpoint_dir, filename))

def load_checkpoint(model, optimizer, scheduler, filename="checkpoint.pth"):
    checkpoint = torch.load(os.path.join(checkpoint_dir, filename))
    model.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    scheduler.load_state_dict(checkpoint['scheduler_state_dict'])
    epoch = checkpoint['epoch']
    loss = checkpoint['loss']
    return model, optimizer, scheduler, epoch, loss

# %%
# Initialize the model, loss function, and optimizer
num_classes = len(full_dataset.classes)  # Number of classes based on dataset
model = CardAttributeCNN(num_classes).to(device)
criterion = nn.CrossEntropyLoss()  # For classification
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, max_lr=0.005, steps_per_epoch=len(train_loader), epochs=50)

# %% [markdown]
# Using BatchNorm needs to tune up the learning rate

# %%
# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler=None, num_epochs=20, debug=False):
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0
        batch_count = 0

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            if debug:
                if batch_count < 10 or (batch_count % 10 == 0 and batch_count <= 100) or (batch_count % 100 == 0):
                    print(f"Batch {batch_count} / {len(train_loader)}, Epoch {epoch+1}")
                batch_count += 1
            optimizer.zero_grad()
            outputs, _ = model(images, True)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            if scheduler is not None:
                scheduler.step()
            running_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        epoch_train_loss = running_loss / len(train_loader)
        epoch_train_acc = 100 * correct / total
        train_losses.append(epoch_train_loss)
        train_accuracies.append(epoch_train_acc)

        # Validation phase
        model.eval()
        val_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

        epoch_val_loss = val_loss / len(val_loader)
        epoch_val_acc = 100 * correct / total
        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_acc)

        # Save checkpoint
        save_checkpoint(model, optimizer, scheduler, epoch, val_loss)

        # Print epoch statistics
        print(f'Epoch [{epoch+1}/{num_epochs}]')
        print(f'Train Loss: {epoch_train_loss:.4f}, Train Accuracy: {epoch_train_acc:.2f}%')
        print(f'Val Loss: {epoch_val_loss:.4f}, Val Accuracy: {epoch_val_acc:.2f}%')
        print('-' * 50)

    return train_losses, val_losses, train_accuracies, val_accuracies

# Train the model
num_epochs = 50
train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model, train_loader, val_loader, criterion, optimizer, scheduler=scheduler, num_epochs=num_epochs, debug=True
)

# Plot training and validation metrics
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(train_losses, label='Train Loss')
plt.plot(val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(train_accuracies, label='Train Accuracy')
plt.plot(val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.title('Training and Validation Accuracy')
plt.legend()
plt.tight_layout()
plt.show()

# Evaluate on test set
def evaluate_model(model, test_loader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_loss = test_loss / len(test_loader)
    test_acc = 100 * correct / total
    print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.2f}%')

evaluate_model(model, test_loader, criterion)

# Save the model (optional)
torch.save(model.state_dict(), 'base_model_v4.pth')
# Out:
# Batch 0 / 472, Epoch 1
# Batch 1 / 472, Epoch 1
# Batch 2 / 472, Epoch 1
# Batch 3 / 472, Epoch 1
# Batch 4 / 472, Epoch 1
# Batch 5 / 472, Epoch 1
# Batch 6 / 472, Epoch 1
# Batch 7 / 472, Epoch 1
# Batch 8 / 472, Epoch 1
# Batch 9 / 472, Epoch 1
# Batch 10 / 472, Epoch 1
# c:\Users\User\miniconda3\envs\card-reader\Lib\site-packages\PIL\Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Batch 20 / 472, Epoch 1
# Batch 30 / 472, Epoch 1
# Batch 40 / 472, Epoch 1
# Batch 50 / 472, Epoch 1
# Batch 60 / 472, Epoch 1
# Batch 70 / 472, Epoch 1
# Batch 80 / 472, Epoch 1
# Batch 90 / 472, Epoch 1
# Batch 100 / 472, Epoch 1
# Batch 200 / 472, Epoch 1
# Batch 300 / 472, Epoch 1
# Batch 400 / 472, Epoch 1
# Epoch [1/50]
# Train Loss: 4.7287, Train Accuracy: 2.97%
# Val Loss: 4.4635, Val Accuracy: 4.08%
# --------------------------------------------------
# Batch 0 / 472, Epoch 2
# Batch 1 / 472, Epoch 2
# Batch 2 / 472, Epoch 2
# Batch 3 / 472, Epoch 2
# Batch 4 / 472, Epoch 2
# Batch 5 / 472, Epoch 2
# Batch 6 / 472, Epoch 2
# Batch 7 / 472, Epoch 2
# Batch 8 / 472, Epoch 2
# Batch 9 / 472, Epoch 2
# Batch 10 / 472, Epoch 2
# Batch 20 / 472, Epoch 2
# Batch 30 / 472, Epoch 2
# Batch 40 / 472, Epoch 2
# Batch 50 / 472, Epoch 2
# Batch 60 / 472, Epoch 2
# Batch 70 / 472, Epoch 2
# Batch 80 / 472, Epoch 2
# Batch 90 / 472, Epoch 2
# Batch 100 / 472, Epoch 2
# Batch 200 / 472, Epoch 2
# Batch 300 / 472, Epoch 2
# Batch 400 / 472, Epoch 2
# Epoch [2/50]
# Train Loss: 4.1756, Train Accuracy: 5.21%
# Val Loss: 4.1278, Val Accuracy: 4.29%
# --------------------------------------------------
# Batch 0 / 472, Epoch 3
# Batch 1 / 472, Epoch 3
# Batch 2 / 472, Epoch 3
# Batch 3 / 472, Epoch 3
# Batch 4 / 472, Epoch 3
# Batch 5 / 472, Epoch 3
# Batch 6 / 472, Epoch 3
# Batch 7 / 472, Epoch 3
# Batch 8 / 472, Epoch 3
# Batch 9 / 472, Epoch 3
# Batch 10 / 472, Epoch 3
# Batch 20 / 472, Epoch 3
# Batch 30 / 472, Epoch 3
# Batch 40 / 472, Epoch 3
# Batch 50 / 472, Epoch 3
# Batch 60 / 472, Epoch 3
# Batch 70 / 472, Epoch 3
# Batch 80 / 472, Epoch 3
# Batch 90 / 472, Epoch 3
# Batch 100 / 472, Epoch 3
# Batch 200 / 472, Epoch 3
# Batch 300 / 472, Epoch 3
# Batch 400 / 472, Epoch 3
# Epoch [3/50]
# Train Loss: 3.6983, Train Accuracy: 7.72%
# Val Loss: 3.5107, Val Accuracy: 9.38%
# --------------------------------------------------
# Batch 0 / 472, Epoch 4
# Batch 1 / 472, Epoch 4
# Batch 2 / 472, Epoch 4
# Batch 3 / 472, Epoch 4
# Batch 4 / 472, Epoch 4
# Batch 5 / 472, Epoch 4
# Batch 6 / 472, Epoch 4
# Batch 7 / 472, Epoch 4
# Batch 8 / 472, Epoch 4
# Batch 9 / 472, Epoch 4
# Batch 10 / 472, Epoch 4
# Batch 20 / 472, Epoch 4
# Batch 30 / 472, Epoch 4
# Batch 40 / 472, Epoch 4
# Batch 50 / 472, Epoch 4
# Batch 60 / 472, Epoch 4
# Batch 70 / 472, Epoch 4
# Batch 80 / 472, Epoch 4
# Batch 90 / 472, Epoch 4
# Batch 100 / 472, Epoch 4
# Batch 200 / 472, Epoch 4
# Batch 300 / 472, Epoch 4
# Batch 400 / 472, Epoch 4
# Epoch [4/50]
# Train Loss: 3.2950, Train Accuracy: 10.11%
# Val Loss: 3.3374, Val Accuracy: 9.38%
# --------------------------------------------------
# Batch 0 / 472, Epoch 5
# Batch 1 / 472, Epoch 5
# Batch 2 / 472, Epoch 5
# Batch 3 / 472, Epoch 5
# Batch 4 / 472, Epoch 5
# Batch 5 / 472, Epoch 5
# Batch 6 / 472, Epoch 5
# Batch 7 / 472, Epoch 5
# Batch 8 / 472, Epoch 5
# Batch 9 / 472, Epoch 5
# Batch 10 / 472, Epoch 5
# Batch 20 / 472, Epoch 5
# Batch 30 / 472, Epoch 5
# Batch 40 / 472, Epoch 5
# Batch 50 / 472, Epoch 5
# Batch 60 / 472, Epoch 5
# Batch 70 / 472, Epoch 5
# Batch 80 / 472, Epoch 5
# Batch 90 / 472, Epoch 5
# Batch 100 / 472, Epoch 5
# Batch 200 / 472, Epoch 5
# Batch 300 / 472, Epoch 5
# Batch 400 / 472, Epoch 5
# Epoch [5/50]
# Train Loss: 3.0767, Train Accuracy: 11.46%
# Val Loss: 3.1005, Val Accuracy: 10.70%
# --------------------------------------------------
# Batch 0 / 472, Epoch 6
# Batch 1 / 472, Epoch 6
# Batch 2 / 472, Epoch 6
# Batch 3 / 472, Epoch 6
# Batch 4 / 472, Epoch 6
# Batch 5 / 472, Epoch 6
# Batch 6 / 472, Epoch 6
# Batch 7 / 472, Epoch 6
# Batch 8 / 472, Epoch 6
# Batch 9 / 472, Epoch 6
# Batch 10 / 472, Epoch 6
# Batch 20 / 472, Epoch 6
# Batch 30 / 472, Epoch 6
# Batch 40 / 472, Epoch 6
# Batch 50 / 472, Epoch 6
# Batch 60 / 472, Epoch 6
# Batch 70 / 472, Epoch 6
# Batch 80 / 472, Epoch 6
# Batch 90 / 472, Epoch 6
# Batch 100 / 472, Epoch 6
# Batch 200 / 472, Epoch 6
# Batch 300 / 472, Epoch 6
# Batch 400 / 472, Epoch 6
# Epoch [6/50]
# Train Loss: 2.9560, Train Accuracy: 13.38%
# Val Loss: 3.4245, Val Accuracy: 11.39%
# --------------------------------------------------
# Batch 0 / 472, Epoch 7
# Batch 1 / 472, Epoch 7
# Batch 2 / 472, Epoch 7
# Batch 3 / 472, Epoch 7
# Batch 4 / 472, Epoch 7
# Batch 5 / 472, Epoch 7
# Batch 6 / 472, Epoch 7
# Batch 7 / 472, Epoch 7
# Batch 8 / 472, Epoch 7
# Batch 9 / 472, Epoch 7
# Batch 10 / 472, Epoch 7
# Batch 20 / 472, Epoch 7
# Batch 30 / 472, Epoch 7
# Batch 40 / 472, Epoch 7
# Batch 50 / 472, Epoch 7
# Batch 60 / 472, Epoch 7
# Batch 70 / 472, Epoch 7
# Batch 80 / 472, Epoch 7
# Batch 90 / 472, Epoch 7
# Batch 100 / 472, Epoch 7
# Batch 200 / 472, Epoch 7
# Batch 300 / 472, Epoch 7
# Batch 400 / 472, Epoch 7
# Epoch [7/50]
# Train Loss: 2.8859, Train Accuracy: 13.97%
# Val Loss: 2.9193, Val Accuracy: 12.77%
# --------------------------------------------------
# Batch 0 / 472, Epoch 8
# Batch 1 / 472, Epoch 8
# Batch 2 / 472, Epoch 8
# Batch 3 / 472, Epoch 8
# Batch 4 / 472, Epoch 8
# Batch 5 / 472, Epoch 8
# Batch 6 / 472, Epoch 8
# Batch 7 / 472, Epoch 8
# Batch 8 / 472, Epoch 8
# Batch 9 / 472, Epoch 8
# Batch 10 / 472, Epoch 8
# Batch 20 / 472, Epoch 8
# Batch 30 / 472, Epoch 8
# Batch 40 / 472, Epoch 8
# Batch 50 / 472, Epoch 8
# Batch 60 / 472, Epoch 8
# Batch 70 / 472, Epoch 8
# Batch 80 / 472, Epoch 8
# Batch 90 / 472, Epoch 8
# Batch 100 / 472, Epoch 8
# Batch 200 / 472, Epoch 8
# Batch 300 / 472, Epoch 8
# Batch 400 / 472, Epoch 8
# Epoch [8/50]
# Train Loss: 2.8065, Train Accuracy: 15.76%
# Val Loss: 3.4444, Val Accuracy: 10.65%
# --------------------------------------------------
# Batch 0 / 472, Epoch 9
# Batch 1 / 472, Epoch 9
# Batch 2 / 472, Epoch 9
# Batch 3 / 472, Epoch 9
# Batch 4 / 472, Epoch 9
# Batch 5 / 472, Epoch 9
# Batch 6 / 472, Epoch 9
# Batch 7 / 472, Epoch 9
# Batch 8 / 472, Epoch 9
# Batch 9 / 472, Epoch 9
# Batch 10 / 472, Epoch 9
# Batch 20 / 472, Epoch 9
# Batch 30 / 472, Epoch 9
# Batch 40 / 472, Epoch 9
# Batch 50 / 472, Epoch 9
# Batch 60 / 472, Epoch 9
# Batch 70 / 472, Epoch 9
# Batch 80 / 472, Epoch 9
# Batch 90 / 472, Epoch 9
# Batch 100 / 472, Epoch 9
# Batch 200 / 472, Epoch 9
# Batch 300 / 472, Epoch 9
# Batch 400 / 472, Epoch 9
# Epoch [9/50]
# Train Loss: 2.7457, Train Accuracy: 17.18%
# Val Loss: 2.7026, Val Accuracy: 17.59%
# --------------------------------------------------
# Batch 0 / 472, Epoch 10
# Batch 1 / 472, Epoch 10
# Batch 2 / 472, Epoch 10
# Batch 3 / 472, Epoch 10
# Batch 4 / 472, Epoch 10
# Batch 5 / 472, Epoch 10
# Batch 6 / 472, Epoch 10
# Batch 7 / 472, Epoch 10
# Batch 8 / 472, Epoch 10
# Batch 9 / 472, Epoch 10
# Batch 10 / 472, Epoch 10
# Batch 20 / 472, Epoch 10
# Batch 30 / 472, Epoch 10
# Batch 40 / 472, Epoch 10
# Batch 50 / 472, Epoch 10
# Batch 60 / 472, Epoch 10
# Batch 70 / 472, Epoch 10
# Batch 80 / 472, Epoch 10
# Batch 90 / 472, Epoch 10
# Batch 100 / 472, Epoch 10
# Batch 200 / 472, Epoch 10
# Batch 300 / 472, Epoch 10
# Batch 400 / 472, Epoch 10
# Epoch [10/50]
# Train Loss: 2.6899, Train Accuracy: 18.27%
# Val Loss: 2.9938, Val Accuracy: 13.35%
# --------------------------------------------------
# Batch 0 / 472, Epoch 11
# Batch 1 / 472, Epoch 11
# Batch 2 / 472, Epoch 11
# Batch 3 / 472, Epoch 11
# Batch 4 / 472, Epoch 11
# Batch 5 / 472, Epoch 11
# Batch 6 / 472, Epoch 11
# Batch 7 / 472, Epoch 11
# Batch 8 / 472, Epoch 11
# Batch 9 / 472, Epoch 11
# Batch 10 / 472, Epoch 11
# Batch 20 / 472, Epoch 11
# Batch 30 / 472, Epoch 11
# Batch 40 / 472, Epoch 11
# Batch 50 / 472, Epoch 11
# Batch 60 / 472, Epoch 11
# Batch 70 / 472, Epoch 11
# Batch 80 / 472, Epoch 11
# Batch 90 / 472, Epoch 11
# Batch 100 / 472, Epoch 11
# Batch 200 / 472, Epoch 11
# Batch 300 / 472, Epoch 11
# Batch 400 / 472, Epoch 11
# Epoch [11/50]
# Train Loss: 2.6060, Train Accuracy: 19.86%
# Val Loss: 2.6809, Val Accuracy: 19.24%
# --------------------------------------------------
# Batch 0 / 472, Epoch 12
# Batch 1 / 472, Epoch 12
# Batch 2 / 472, Epoch 12
# Batch 3 / 472, Epoch 12
# Batch 4 / 472, Epoch 12
# Batch 5 / 472, Epoch 12
# Batch 6 / 472, Epoch 12
# Batch 7 / 472, Epoch 12
# Batch 8 / 472, Epoch 12
# Batch 9 / 472, Epoch 12
# Batch 10 / 472, Epoch 12
# Batch 20 / 472, Epoch 12
# Batch 30 / 472, Epoch 12
# Batch 40 / 472, Epoch 12
# Batch 50 / 472, Epoch 12
# Batch 60 / 472, Epoch 12
# Batch 70 / 472, Epoch 12
# Batch 80 / 472, Epoch 12
# Batch 90 / 472, Epoch 12
# Batch 100 / 472, Epoch 12
# Batch 200 / 472, Epoch 12
# Batch 300 / 472, Epoch 12
# Batch 400 / 472, Epoch 12
# Epoch [12/50]
# Train Loss: 2.5305, Train Accuracy: 21.67%
# Val Loss: 2.5160, Val Accuracy: 23.21%
# --------------------------------------------------
# Batch 0 / 472, Epoch 13
# Batch 1 / 472, Epoch 13
# Batch 2 / 472, Epoch 13
# Batch 3 / 472, Epoch 13
# Batch 4 / 472, Epoch 13
# Batch 5 / 472, Epoch 13
# Batch 6 / 472, Epoch 13
# Batch 7 / 472, Epoch 13
# Batch 8 / 472, Epoch 13
# Batch 9 / 472, Epoch 13
# Batch 10 / 472, Epoch 13
# Batch 20 / 472, Epoch 13
# Batch 30 / 472, Epoch 13
# Batch 40 / 472, Epoch 13
# Batch 50 / 472, Epoch 13
# Batch 60 / 472, Epoch 13
# Batch 70 / 472, Epoch 13
# Batch 80 / 472, Epoch 13
# Batch 90 / 472, Epoch 13
# Batch 100 / 472, Epoch 13
# Batch 200 / 472, Epoch 13
# Batch 300 / 472, Epoch 13
# Batch 400 / 472, Epoch 13
# Epoch [13/50]
# Train Loss: 2.4599, Train Accuracy: 23.73%
# Val Loss: 2.4500, Val Accuracy: 23.37%
# --------------------------------------------------
# Batch 0 / 472, Epoch 14
# Batch 1 / 472, Epoch 14
# Batch 2 / 472, Epoch 14
# Batch 3 / 472, Epoch 14
# Batch 4 / 472, Epoch 14
# Batch 5 / 472, Epoch 14
# Batch 6 / 472, Epoch 14
# Batch 7 / 472, Epoch 14
# Batch 8 / 472, Epoch 14
# Batch 9 / 472, Epoch 14
# Batch 10 / 472, Epoch 14
# Batch 20 / 472, Epoch 14
# Batch 30 / 472, Epoch 14
# Batch 40 / 472, Epoch 14
# Batch 50 / 472, Epoch 14
# Batch 60 / 472, Epoch 14
# Batch 70 / 472, Epoch 14
# Batch 80 / 472, Epoch 14
# Batch 90 / 472, Epoch 14
# Batch 100 / 472, Epoch 14
# Batch 200 / 472, Epoch 14
# Batch 300 / 472, Epoch 14
# Batch 400 / 472, Epoch 14
# Epoch [14/50]
# Train Loss: 2.3837, Train Accuracy: 26.16%
# Val Loss: 2.3620, Val Accuracy: 26.34%
# --------------------------------------------------
# Batch 0 / 472, Epoch 15
# Batch 1 / 472, Epoch 15
# Batch 2 / 472, Epoch 15
# Batch 3 / 472, Epoch 15
# Batch 4 / 472, Epoch 15
# Batch 5 / 472, Epoch 15
# Batch 6 / 472, Epoch 15
# Batch 7 / 472, Epoch 15
# Batch 8 / 472, Epoch 15
# Batch 9 / 472, Epoch 15
# Batch 10 / 472, Epoch 15
# Batch 20 / 472, Epoch 15
# Batch 30 / 472, Epoch 15
# Batch 40 / 472, Epoch 15
# Batch 50 / 472, Epoch 15
# Batch 60 / 472, Epoch 15
# Batch 70 / 472, Epoch 15
# Batch 80 / 472, Epoch 15
# Batch 90 / 472, Epoch 15
# Batch 100 / 472, Epoch 15
# Batch 200 / 472, Epoch 15
# Batch 300 / 472, Epoch 15
# Batch 400 / 472, Epoch 15
# Epoch [15/50]
# Train Loss: 2.3216, Train Accuracy: 26.88%
# Val Loss: 2.1720, Val Accuracy: 29.78%
# --------------------------------------------------
# Batch 0 / 472, Epoch 16
# Batch 1 / 472, Epoch 16
# Batch 2 / 472, Epoch 16
# Batch 3 / 472, Epoch 16
# Batch 4 / 472, Epoch 16
# Batch 5 / 472, Epoch 16
# Batch 6 / 472, Epoch 16
# Batch 7 / 472, Epoch 16
# Batch 8 / 472, Epoch 16
# Batch 9 / 472, Epoch 16
# Batch 10 / 472, Epoch 16
# Batch 20 / 472, Epoch 16
# Batch 30 / 472, Epoch 16
# Batch 40 / 472, Epoch 16
# Batch 50 / 472, Epoch 16
# Batch 60 / 472, Epoch 16
# Batch 70 / 472, Epoch 16
# Batch 80 / 472, Epoch 16
# Batch 90 / 472, Epoch 16
# Batch 100 / 472, Epoch 16
# Batch 200 / 472, Epoch 16
# Batch 300 / 472, Epoch 16
# Batch 400 / 472, Epoch 16
# Epoch [16/50]
# Train Loss: 2.2411, Train Accuracy: 29.24%
# Val Loss: 2.2725, Val Accuracy: 29.52%
# --------------------------------------------------
# Batch 0 / 472, Epoch 17
# Batch 1 / 472, Epoch 17
# Batch 2 / 472, Epoch 17
# Batch 3 / 472, Epoch 17
# Batch 4 / 472, Epoch 17
# Batch 5 / 472, Epoch 17
# Batch 6 / 472, Epoch 17
# Batch 7 / 472, Epoch 17
# Batch 8 / 472, Epoch 17
# Batch 9 / 472, Epoch 17
# Batch 10 / 472, Epoch 17
# Batch 20 / 472, Epoch 17
# Batch 30 / 472, Epoch 17
# Batch 40 / 472, Epoch 17
# Batch 50 / 472, Epoch 17
# Batch 60 / 472, Epoch 17
# Batch 70 / 472, Epoch 17
# Batch 80 / 472, Epoch 17
# Batch 90 / 472, Epoch 17
# Batch 100 / 472, Epoch 17
# Batch 200 / 472, Epoch 17
# Batch 300 / 472, Epoch 17
# Batch 400 / 472, Epoch 17
# Epoch [17/50]
# Train Loss: 2.1651, Train Accuracy: 30.85%
# Val Loss: 2.2782, Val Accuracy: 29.94%
# --------------------------------------------------
# Batch 0 / 472, Epoch 18
# Batch 1 / 472, Epoch 18
# Batch 2 / 472, Epoch 18
# Batch 3 / 472, Epoch 18
# Batch 4 / 472, Epoch 18
# Batch 5 / 472, Epoch 18
# Batch 6 / 472, Epoch 18
# Batch 7 / 472, Epoch 18
# Batch 8 / 472, Epoch 18
# Batch 9 / 472, Epoch 18
# Batch 10 / 472, Epoch 18
# Batch 20 / 472, Epoch 18
# Batch 30 / 472, Epoch 18
# Batch 40 / 472, Epoch 18
# Batch 50 / 472, Epoch 18
# Batch 60 / 472, Epoch 18
# Batch 70 / 472, Epoch 18
# Batch 80 / 472, Epoch 18
# Batch 90 / 472, Epoch 18
# Batch 100 / 472, Epoch 18
# Batch 200 / 472, Epoch 18
# Batch 300 / 472, Epoch 18
# Batch 400 / 472, Epoch 18
# Epoch [18/50]
# Train Loss: 2.1168, Train Accuracy: 32.24%
# Val Loss: 2.0814, Val Accuracy: 31.48%
# --------------------------------------------------
# Batch 0 / 472, Epoch 19
# Batch 1 / 472, Epoch 19
# Batch 2 / 472, Epoch 19
# Batch 3 / 472, Epoch 19
# Batch 4 / 472, Epoch 19
# Batch 5 / 472, Epoch 19
# Batch 6 / 472, Epoch 19
# Batch 7 / 472, Epoch 19
# Batch 8 / 472, Epoch 19
# Batch 9 / 472, Epoch 19
# Batch 10 / 472, Epoch 19
# Batch 20 / 472, Epoch 19
# Batch 30 / 472, Epoch 19
# Batch 40 / 472, Epoch 19
# Batch 50 / 472, Epoch 19
# Batch 60 / 472, Epoch 19
# Batch 70 / 472, Epoch 19
# Batch 80 / 472, Epoch 19
# Batch 90 / 472, Epoch 19
# Batch 100 / 472, Epoch 19
# Batch 200 / 472, Epoch 19
# Batch 300 / 472, Epoch 19
# Batch 400 / 472, Epoch 19
# Epoch [19/50]
# Train Loss: 2.0650, Train Accuracy: 33.75%
# Val Loss: 2.4900, Val Accuracy: 29.15%
# --------------------------------------------------
# Batch 0 / 472, Epoch 20
# Batch 1 / 472, Epoch 20
# Batch 2 / 472, Epoch 20
# Batch 3 / 472, Epoch 20
# Batch 4 / 472, Epoch 20
# Batch 5 / 472, Epoch 20
# Batch 6 / 472, Epoch 20
# Batch 7 / 472, Epoch 20
# Batch 8 / 472, Epoch 20
# Batch 9 / 472, Epoch 20
# Batch 10 / 472, Epoch 20
# Batch 20 / 472, Epoch 20
# Batch 30 / 472, Epoch 20
# Batch 40 / 472, Epoch 20
# Batch 50 / 472, Epoch 20
# Batch 60 / 472, Epoch 20
# Batch 70 / 472, Epoch 20
# Batch 80 / 472, Epoch 20
# Batch 90 / 472, Epoch 20
# Batch 100 / 472, Epoch 20
# Batch 200 / 472, Epoch 20
# Batch 300 / 472, Epoch 20
# Batch 400 / 472, Epoch 20
# Epoch [20/50]
# Train Loss: 2.0019, Train Accuracy: 34.31%
# Val Loss: 1.8771, Val Accuracy: 37.78%
# --------------------------------------------------
# Batch 0 / 472, Epoch 21
# Batch 1 / 472, Epoch 21
# Batch 2 / 472, Epoch 21
# Batch 3 / 472, Epoch 21
# Batch 4 / 472, Epoch 21
# Batch 5 / 472, Epoch 21
# Batch 6 / 472, Epoch 21
# Batch 7 / 472, Epoch 21
# Batch 8 / 472, Epoch 21
# Batch 9 / 472, Epoch 21
# Batch 10 / 472, Epoch 21
# Batch 20 / 472, Epoch 21
# Batch 30 / 472, Epoch 21
# Batch 40 / 472, Epoch 21
# Batch 50 / 472, Epoch 21
# Batch 60 / 472, Epoch 21
# Batch 70 / 472, Epoch 21
# Batch 80 / 472, Epoch 21
# Batch 90 / 472, Epoch 21
# Batch 100 / 472, Epoch 21
# Batch 200 / 472, Epoch 21
# Batch 300 / 472, Epoch 21
# Batch 400 / 472, Epoch 21
# Epoch [21/50]
# Train Loss: 1.9539, Train Accuracy: 36.59%
# Val Loss: 1.8784, Val Accuracy: 39.80%
# --------------------------------------------------
# Batch 0 / 472, Epoch 22
# Batch 1 / 472, Epoch 22
# Batch 2 / 472, Epoch 22
# Batch 3 / 472, Epoch 22
# Batch 4 / 472, Epoch 22
# Batch 5 / 472, Epoch 22
# Batch 6 / 472, Epoch 22
# Batch 7 / 472, Epoch 22
# Batch 8 / 472, Epoch 22
# Batch 9 / 472, Epoch 22
# Batch 10 / 472, Epoch 22
# Batch 20 / 472, Epoch 22
# Batch 30 / 472, Epoch 22
# Batch 40 / 472, Epoch 22
# Batch 50 / 472, Epoch 22
# Batch 60 / 472, Epoch 22
# Batch 70 / 472, Epoch 22
# Batch 80 / 472, Epoch 22
# Batch 90 / 472, Epoch 22
# Batch 100 / 472, Epoch 22
# Batch 200 / 472, Epoch 22
# Batch 300 / 472, Epoch 22
# Batch 400 / 472, Epoch 22
# Epoch [22/50]
# Train Loss: 1.9023, Train Accuracy: 37.72%
# Val Loss: 1.8170, Val Accuracy: 39.85%
# --------------------------------------------------
# Batch 0 / 472, Epoch 23
# Batch 1 / 472, Epoch 23
# Batch 2 / 472, Epoch 23
# Batch 3 / 472, Epoch 23
# Batch 4 / 472, Epoch 23
# Batch 5 / 472, Epoch 23
# Batch 6 / 472, Epoch 23
# Batch 7 / 472, Epoch 23
# Batch 8 / 472, Epoch 23
# Batch 9 / 472, Epoch 23
# Batch 10 / 472, Epoch 23
# Batch 20 / 472, Epoch 23
# Batch 30 / 472, Epoch 23
# Batch 40 / 472, Epoch 23
# Batch 50 / 472, Epoch 23
# Batch 60 / 472, Epoch 23
# Batch 70 / 472, Epoch 23
# Batch 80 / 472, Epoch 23
# Batch 90 / 472, Epoch 23
# Batch 100 / 472, Epoch 23
# Batch 200 / 472, Epoch 23
# Batch 300 / 472, Epoch 23
# Batch 400 / 472, Epoch 23
# Epoch [23/50]
# Train Loss: 1.8699, Train Accuracy: 38.51%
# Val Loss: 1.8046, Val Accuracy: 40.91%
# --------------------------------------------------
# Batch 0 / 472, Epoch 24
# Batch 1 / 472, Epoch 24
# Batch 2 / 472, Epoch 24
# Batch 3 / 472, Epoch 24
# Batch 4 / 472, Epoch 24
# Batch 5 / 472, Epoch 24
# Batch 6 / 472, Epoch 24
# Batch 7 / 472, Epoch 24
# Batch 8 / 472, Epoch 24
# Batch 9 / 472, Epoch 24
# Batch 10 / 472, Epoch 24
# Batch 20 / 472, Epoch 24
# Batch 30 / 472, Epoch 24
# Batch 40 / 472, Epoch 24
# Batch 50 / 472, Epoch 24
# Batch 60 / 472, Epoch 24
# Batch 70 / 472, Epoch 24
# Batch 80 / 472, Epoch 24
# Batch 90 / 472, Epoch 24
# Batch 100 / 472, Epoch 24
# Batch 200 / 472, Epoch 24
# Batch 300 / 472, Epoch 24
# Batch 400 / 472, Epoch 24
# Epoch [24/50]
# Train Loss: 1.8196, Train Accuracy: 39.75%
# Val Loss: 1.7922, Val Accuracy: 40.33%
# --------------------------------------------------
# Batch 0 / 472, Epoch 25
# Batch 1 / 472, Epoch 25
# Batch 2 / 472, Epoch 25
# Batch 3 / 472, Epoch 25
# Batch 4 / 472, Epoch 25
# Batch 5 / 472, Epoch 25
# Batch 6 / 472, Epoch 25
# Batch 7 / 472, Epoch 25
# Batch 8 / 472, Epoch 25
# Batch 9 / 472, Epoch 25
# Batch 10 / 472, Epoch 25
# Batch 20 / 472, Epoch 25
# Batch 30 / 472, Epoch 25
# Batch 40 / 472, Epoch 25
# Batch 50 / 472, Epoch 25
# Batch 60 / 472, Epoch 25
# Batch 70 / 472, Epoch 25
# Batch 80 / 472, Epoch 25
# Batch 90 / 472, Epoch 25
# Batch 100 / 472, Epoch 25
# Batch 200 / 472, Epoch 25
# Batch 300 / 472, Epoch 25
# Batch 400 / 472, Epoch 25
# Epoch [25/50]
# Train Loss: 1.7769, Train Accuracy: 41.48%
# Val Loss: 1.6886, Val Accuracy: 43.30%
# --------------------------------------------------
# Batch 0 / 472, Epoch 26
# Batch 1 / 472, Epoch 26
# Batch 2 / 472, Epoch 26
# Batch 3 / 472, Epoch 26
# Batch 4 / 472, Epoch 26
# Batch 5 / 472, Epoch 26
# Batch 6 / 472, Epoch 26
# Batch 7 / 472, Epoch 26
# Batch 8 / 472, Epoch 26
# Batch 9 / 472, Epoch 26
# Batch 10 / 472, Epoch 26
# Batch 20 / 472, Epoch 26
# Batch 30 / 472, Epoch 26
# Batch 40 / 472, Epoch 26
# Batch 50 / 472, Epoch 26
# Batch 60 / 472, Epoch 26
# Batch 70 / 472, Epoch 26
# Batch 80 / 472, Epoch 26
# Batch 90 / 472, Epoch 26
# Batch 100 / 472, Epoch 26
# Batch 200 / 472, Epoch 26
# Batch 300 / 472, Epoch 26
# Batch 400 / 472, Epoch 26
# Epoch [26/50]
# Train Loss: 1.7336, Train Accuracy: 42.53%
# Val Loss: 1.6570, Val Accuracy: 46.21%
# --------------------------------------------------
# Batch 0 / 472, Epoch 27
# Batch 1 / 472, Epoch 27
# Batch 2 / 472, Epoch 27
# Batch 3 / 472, Epoch 27
# Batch 4 / 472, Epoch 27
# Batch 5 / 472, Epoch 27
# Batch 6 / 472, Epoch 27
# Batch 7 / 472, Epoch 27
# Batch 8 / 472, Epoch 27
# Batch 9 / 472, Epoch 27
# Batch 10 / 472, Epoch 27
# Batch 20 / 472, Epoch 27
# Batch 30 / 472, Epoch 27
# Batch 40 / 472, Epoch 27
# Batch 50 / 472, Epoch 27
# Batch 60 / 472, Epoch 27
# Batch 70 / 472, Epoch 27
# Batch 80 / 472, Epoch 27
# Batch 90 / 472, Epoch 27
# Batch 100 / 472, Epoch 27
# Batch 200 / 472, Epoch 27
# Batch 300 / 472, Epoch 27
# Batch 400 / 472, Epoch 27
# Epoch [27/50]
# Train Loss: 1.7033, Train Accuracy: 43.02%
# Val Loss: 1.6222, Val Accuracy: 46.85%
# --------------------------------------------------
# Batch 0 / 472, Epoch 28
# Batch 1 / 472, Epoch 28
# Batch 2 / 472, Epoch 28
# Batch 3 / 472, Epoch 28
# Batch 4 / 472, Epoch 28
# Batch 5 / 472, Epoch 28
# Batch 6 / 472, Epoch 28
# Batch 7 / 472, Epoch 28
# Batch 8 / 472, Epoch 28
# Batch 9 / 472, Epoch 28
# Batch 10 / 472, Epoch 28
# Batch 20 / 472, Epoch 28
# Batch 30 / 472, Epoch 28
# Batch 40 / 472, Epoch 28
# Batch 50 / 472, Epoch 28
# Batch 60 / 472, Epoch 28
# Batch 70 / 472, Epoch 28
# Batch 80 / 472, Epoch 28
# Batch 90 / 472, Epoch 28
# Batch 100 / 472, Epoch 28
# Batch 200 / 472, Epoch 28
# Batch 300 / 472, Epoch 28
# Batch 400 / 472, Epoch 28
# Epoch [28/50]
# Train Loss: 1.6545, Train Accuracy: 44.86%
# Val Loss: 1.6045, Val Accuracy: 46.90%
# --------------------------------------------------
# Batch 0 / 472, Epoch 29
# Batch 1 / 472, Epoch 29
# Batch 2 / 472, Epoch 29
# Batch 3 / 472, Epoch 29
# Batch 4 / 472, Epoch 29
# Batch 5 / 472, Epoch 29
# Batch 6 / 472, Epoch 29
# Batch 7 / 472, Epoch 29
# Batch 8 / 472, Epoch 29
# Batch 9 / 472, Epoch 29
# Batch 10 / 472, Epoch 29
# Batch 20 / 472, Epoch 29
# Batch 30 / 472, Epoch 29
# Batch 40 / 472, Epoch 29
# Batch 50 / 472, Epoch 29
# Batch 60 / 472, Epoch 29
# Batch 70 / 472, Epoch 29
# Batch 80 / 472, Epoch 29
# Batch 90 / 472, Epoch 29
# Batch 100 / 472, Epoch 29
# Batch 200 / 472, Epoch 29
# Batch 300 / 472, Epoch 29
# Batch 400 / 472, Epoch 29
# Epoch [29/50]
# Train Loss: 1.6241, Train Accuracy: 45.18%
# Val Loss: 1.5763, Val Accuracy: 49.07%
# --------------------------------------------------
# Batch 0 / 472, Epoch 30
# Batch 1 / 472, Epoch 30
# Batch 2 / 472, Epoch 30
# Batch 3 / 472, Epoch 30
# Batch 4 / 472, Epoch 30
# Batch 5 / 472, Epoch 30
# Batch 6 / 472, Epoch 30
# Batch 7 / 472, Epoch 30
# Batch 8 / 472, Epoch 30
# Batch 9 / 472, Epoch 30
# Batch 10 / 472, Epoch 30
# Batch 20 / 472, Epoch 30
# Batch 30 / 472, Epoch 30
# Batch 40 / 472, Epoch 30
# Batch 50 / 472, Epoch 30
# Batch 60 / 472, Epoch 30
# Batch 70 / 472, Epoch 30
# Batch 80 / 472, Epoch 30
# Batch 90 / 472, Epoch 30
# Batch 100 / 472, Epoch 30
# Batch 200 / 472, Epoch 30
# Batch 300 / 472, Epoch 30
# Batch 400 / 472, Epoch 30
# Epoch [30/50]
# Train Loss: 1.5855, Train Accuracy: 47.01%
# Val Loss: 1.5238, Val Accuracy: 50.93%
# --------------------------------------------------
# Batch 0 / 472, Epoch 31
# Batch 1 / 472, Epoch 31
# Batch 2 / 472, Epoch 31
# Batch 3 / 472, Epoch 31
# Batch 4 / 472, Epoch 31
# Batch 5 / 472, Epoch 31
# Batch 6 / 472, Epoch 31
# Batch 7 / 472, Epoch 31
# Batch 8 / 472, Epoch 31
# Batch 9 / 472, Epoch 31
# Batch 10 / 472, Epoch 31
# Batch 20 / 472, Epoch 31
# Batch 30 / 472, Epoch 31
# Batch 40 / 472, Epoch 31
# Batch 50 / 472, Epoch 31
# Batch 60 / 472, Epoch 31
# Batch 70 / 472, Epoch 31
# Batch 80 / 472, Epoch 31
# Batch 90 / 472, Epoch 31
# Batch 100 / 472, Epoch 31
# Batch 200 / 472, Epoch 31
# Batch 300 / 472, Epoch 31
# Batch 400 / 472, Epoch 31
# Epoch [31/50]
# Train Loss: 1.5531, Train Accuracy: 47.46%
# Val Loss: 1.4708, Val Accuracy: 51.25%
# --------------------------------------------------
# Batch 0 / 472, Epoch 32
# Batch 1 / 472, Epoch 32
# Batch 2 / 472, Epoch 32
# Batch 3 / 472, Epoch 32
# Batch 4 / 472, Epoch 32
# Batch 5 / 472, Epoch 32
# Batch 6 / 472, Epoch 32
# Batch 7 / 472, Epoch 32
# Batch 8 / 472, Epoch 32
# Batch 9 / 472, Epoch 32
# Batch 10 / 472, Epoch 32
# Batch 20 / 472, Epoch 32
# Batch 30 / 472, Epoch 32
# Batch 40 / 472, Epoch 32
# Batch 50 / 472, Epoch 32
# Batch 60 / 472, Epoch 32
# Batch 70 / 472, Epoch 32
# Batch 80 / 472, Epoch 32
# Batch 90 / 472, Epoch 32
# Batch 100 / 472, Epoch 32
# Batch 200 / 472, Epoch 32
# Batch 300 / 472, Epoch 32
# Batch 400 / 472, Epoch 32
# Epoch [32/50]
# Train Loss: 1.4957, Train Accuracy: 49.48%
# Val Loss: 1.4236, Val Accuracy: 52.52%
# --------------------------------------------------
# Batch 0 / 472, Epoch 33
# Batch 1 / 472, Epoch 33
# Batch 2 / 472, Epoch 33
# Batch 3 / 472, Epoch 33
# Batch 4 / 472, Epoch 33
# Batch 5 / 472, Epoch 33
# Batch 6 / 472, Epoch 33
# Batch 7 / 472, Epoch 33
# Batch 8 / 472, Epoch 33
# Batch 9 / 472, Epoch 33
# Batch 10 / 472, Epoch 33
# Batch 20 / 472, Epoch 33
# Batch 30 / 472, Epoch 33
# Batch 40 / 472, Epoch 33
# Batch 50 / 472, Epoch 33
# Batch 60 / 472, Epoch 33
# Batch 70 / 472, Epoch 33
# Batch 80 / 472, Epoch 33
# Batch 90 / 472, Epoch 33
# Batch 100 / 472, Epoch 33
# Batch 200 / 472, Epoch 33
# Batch 300 / 472, Epoch 33
# Batch 400 / 472, Epoch 33
# Epoch [33/50]
# Train Loss: 1.4671, Train Accuracy: 50.15%
# Val Loss: 1.4248, Val Accuracy: 52.62%
# --------------------------------------------------
# Batch 0 / 472, Epoch 34
# Batch 1 / 472, Epoch 34
# Batch 2 / 472, Epoch 34
# Batch 3 / 472, Epoch 34
# Batch 4 / 472, Epoch 34
# Batch 5 / 472, Epoch 34
# Batch 6 / 472, Epoch 34
# Batch 7 / 472, Epoch 34
# Batch 8 / 472, Epoch 34
# Batch 9 / 472, Epoch 34
# Batch 10 / 472, Epoch 34
# Batch 20 / 472, Epoch 34
# Batch 30 / 472, Epoch 34
# Batch 40 / 472, Epoch 34
# Batch 50 / 472, Epoch 34
# Batch 60 / 472, Epoch 34
# Batch 70 / 472, Epoch 34
# Batch 80 / 472, Epoch 34
# Batch 90 / 472, Epoch 34
# Batch 100 / 472, Epoch 34
# Batch 200 / 472, Epoch 34
# Batch 300 / 472, Epoch 34
# Batch 400 / 472, Epoch 34
# Epoch [34/50]
# Train Loss: 1.4257, Train Accuracy: 51.70%
# Val Loss: 1.3371, Val Accuracy: 54.85%
# --------------------------------------------------
# Batch 0 / 472, Epoch 35
# Batch 1 / 472, Epoch 35
# Batch 2 / 472, Epoch 35
# Batch 3 / 472, Epoch 35
# Batch 4 / 472, Epoch 35
# Batch 5 / 472, Epoch 35
# Batch 6 / 472, Epoch 35
# Batch 7 / 472, Epoch 35
# Batch 8 / 472, Epoch 35
# Batch 9 / 472, Epoch 35
# Batch 10 / 472, Epoch 35
# Batch 20 / 472, Epoch 35
# Batch 30 / 472, Epoch 35
# Batch 40 / 472, Epoch 35
# Batch 50 / 472, Epoch 35
# Batch 60 / 472, Epoch 35
# Batch 70 / 472, Epoch 35
# Batch 80 / 472, Epoch 35
# Batch 90 / 472, Epoch 35
# Batch 100 / 472, Epoch 35
# Batch 200 / 472, Epoch 35
# Batch 300 / 472, Epoch 35
# Batch 400 / 472, Epoch 35
# Epoch [35/50]
# Train Loss: 1.3941, Train Accuracy: 51.75%
# Val Loss: 1.3368, Val Accuracy: 55.70%
# --------------------------------------------------
# Batch 0 / 472, Epoch 36
# Batch 1 / 472, Epoch 36
# Batch 2 / 472, Epoch 36
# Batch 3 / 472, Epoch 36
# Batch 4 / 472, Epoch 36
# Batch 5 / 472, Epoch 36
# Batch 6 / 472, Epoch 36
# Batch 7 / 472, Epoch 36
# Batch 8 / 472, Epoch 36
# Batch 9 / 472, Epoch 36
# Batch 10 / 472, Epoch 36
# Batch 20 / 472, Epoch 36
# Batch 30 / 472, Epoch 36
# Batch 40 / 472, Epoch 36
# Batch 50 / 472, Epoch 36
# Batch 60 / 472, Epoch 36
# Batch 70 / 472, Epoch 36
# Batch 80 / 472, Epoch 36
# Batch 90 / 472, Epoch 36
# Batch 100 / 472, Epoch 36
# Batch 200 / 472, Epoch 36
# Batch 300 / 472, Epoch 36
# Batch 400 / 472, Epoch 36
# Epoch [36/50]
# Train Loss: 1.3529, Train Accuracy: 53.69%
# Val Loss: 1.2433, Val Accuracy: 58.45%
# --------------------------------------------------
# Batch 0 / 472, Epoch 37
# Batch 1 / 472, Epoch 37
# Batch 2 / 472, Epoch 37
# Batch 3 / 472, Epoch 37
# Batch 4 / 472, Epoch 37
# Batch 5 / 472, Epoch 37
# Batch 6 / 472, Epoch 37
# Batch 7 / 472, Epoch 37
# Batch 8 / 472, Epoch 37
# Batch 9 / 472, Epoch 37
# Batch 10 / 472, Epoch 37
# Batch 20 / 472, Epoch 37
# Batch 30 / 472, Epoch 37
# Batch 40 / 472, Epoch 37
# Batch 50 / 472, Epoch 37
# Batch 60 / 472, Epoch 37
# Batch 70 / 472, Epoch 37
# Batch 80 / 472, Epoch 37
# Batch 90 / 472, Epoch 37
# Batch 100 / 472, Epoch 37
# Batch 200 / 472, Epoch 37
# Batch 300 / 472, Epoch 37
# Batch 400 / 472, Epoch 37
# Epoch [37/50]
# Train Loss: 1.3242, Train Accuracy: 54.88%
# Val Loss: 1.2714, Val Accuracy: 59.62%
# --------------------------------------------------
# Batch 0 / 472, Epoch 38
# Batch 1 / 472, Epoch 38
# Batch 2 / 472, Epoch 38
# Batch 3 / 472, Epoch 38
# Batch 4 / 472, Epoch 38
# Batch 5 / 472, Epoch 38
# Batch 6 / 472, Epoch 38
# Batch 7 / 472, Epoch 38
# Batch 8 / 472, Epoch 38
# Batch 9 / 472, Epoch 38
# Batch 10 / 472, Epoch 38
# Batch 20 / 472, Epoch 38
# Batch 30 / 472, Epoch 38
# Batch 40 / 472, Epoch 38
# Batch 50 / 472, Epoch 38
# Batch 60 / 472, Epoch 38
# Batch 70 / 472, Epoch 38
# Batch 80 / 472, Epoch 38
# Batch 90 / 472, Epoch 38
# Batch 100 / 472, Epoch 38
# Batch 200 / 472, Epoch 38
# Batch 300 / 472, Epoch 38
# Batch 400 / 472, Epoch 38
# Epoch [38/50]
# Train Loss: 1.2800, Train Accuracy: 55.93%
# Val Loss: 1.1926, Val Accuracy: 60.73%
# --------------------------------------------------
# Batch 0 / 472, Epoch 39
# Batch 1 / 472, Epoch 39
# Batch 2 / 472, Epoch 39
# Batch 3 / 472, Epoch 39
# Batch 4 / 472, Epoch 39
# Batch 5 / 472, Epoch 39
# Batch 6 / 472, Epoch 39
# Batch 7 / 472, Epoch 39
# Batch 8 / 472, Epoch 39
# Batch 9 / 472, Epoch 39
# Batch 10 / 472, Epoch 39
# Batch 20 / 472, Epoch 39
# Batch 30 / 472, Epoch 39
# Batch 40 / 472, Epoch 39
# Batch 50 / 472, Epoch 39
# Batch 60 / 472, Epoch 39
# Batch 70 / 472, Epoch 39
# Batch 80 / 472, Epoch 39
# Batch 90 / 472, Epoch 39
# Batch 100 / 472, Epoch 39
# Batch 200 / 472, Epoch 39
# Batch 300 / 472, Epoch 39
# Batch 400 / 472, Epoch 39
# Epoch [39/50]
# Train Loss: 1.2436, Train Accuracy: 57.69%
# Val Loss: 1.1309, Val Accuracy: 62.32%
# --------------------------------------------------
# Batch 0 / 472, Epoch 40
# Batch 1 / 472, Epoch 40
# Batch 2 / 472, Epoch 40
# Batch 3 / 472, Epoch 40
# Batch 4 / 472, Epoch 40
# Batch 5 / 472, Epoch 40
# Batch 6 / 472, Epoch 40
# Batch 7 / 472, Epoch 40
# Batch 8 / 472, Epoch 40
# Batch 9 / 472, Epoch 40
# Batch 10 / 472, Epoch 40
# Batch 20 / 472, Epoch 40
# Batch 30 / 472, Epoch 40
# Batch 40 / 472, Epoch 40
# Batch 50 / 472, Epoch 40
# Batch 60 / 472, Epoch 40
# Batch 70 / 472, Epoch 40
# Batch 80 / 472, Epoch 40
# Batch 90 / 472, Epoch 40
# Batch 100 / 472, Epoch 40
# Batch 200 / 472, Epoch 40
# Batch 300 / 472, Epoch 40
# Batch 400 / 472, Epoch 40
# Epoch [40/50]
# Train Loss: 1.2241, Train Accuracy: 58.27%
# Val Loss: 1.1300, Val Accuracy: 63.17%
# --------------------------------------------------
# Batch 0 / 472, Epoch 41
# Batch 1 / 472, Epoch 41
# Batch 2 / 472, Epoch 41
# Batch 3 / 472, Epoch 41
# Batch 4 / 472, Epoch 41
# Batch 5 / 472, Epoch 41
# Batch 6 / 472, Epoch 41
# Batch 7 / 472, Epoch 41
# Batch 8 / 472, Epoch 41
# Batch 9 / 472, Epoch 41
# Batch 10 / 472, Epoch 41
# Batch 20 / 472, Epoch 41
# Batch 30 / 472, Epoch 41
# Batch 40 / 472, Epoch 41
# Batch 50 / 472, Epoch 41
# Batch 60 / 472, Epoch 41
# Batch 70 / 472, Epoch 41
# Batch 80 / 472, Epoch 41
# Batch 90 / 472, Epoch 41
# Batch 100 / 472, Epoch 41
# Batch 200 / 472, Epoch 41
# Batch 300 / 472, Epoch 41
# Batch 400 / 472, Epoch 41
# Epoch [41/50]
# Train Loss: 1.1868, Train Accuracy: 59.32%
# Val Loss: 1.0966, Val Accuracy: 63.59%
# --------------------------------------------------
# Batch 0 / 472, Epoch 42
# Batch 1 / 472, Epoch 42
# Batch 2 / 472, Epoch 42
# Batch 3 / 472, Epoch 42
# Batch 4 / 472, Epoch 42
# Batch 5 / 472, Epoch 42
# Batch 6 / 472, Epoch 42
# Batch 7 / 472, Epoch 42
# Batch 8 / 472, Epoch 42
# Batch 9 / 472, Epoch 42
# Batch 10 / 472, Epoch 42
# Batch 20 / 472, Epoch 42
# Batch 30 / 472, Epoch 42
# Batch 40 / 472, Epoch 42
# Batch 50 / 472, Epoch 42
# Batch 60 / 472, Epoch 42
# Batch 70 / 472, Epoch 42
# Batch 80 / 472, Epoch 42
# Batch 90 / 472, Epoch 42
# Batch 100 / 472, Epoch 42
# Batch 200 / 472, Epoch 42
# Batch 300 / 472, Epoch 42
# Batch 400 / 472, Epoch 42
# Epoch [42/50]
# Train Loss: 1.1687, Train Accuracy: 59.59%
# Val Loss: 1.0773, Val Accuracy: 64.71%
# --------------------------------------------------
# Batch 0 / 472, Epoch 43
# Batch 1 / 472, Epoch 43
# Batch 2 / 472, Epoch 43
# Batch 3 / 472, Epoch 43
# Batch 4 / 472, Epoch 43
# Batch 5 / 472, Epoch 43
# Batch 6 / 472, Epoch 43
# Batch 7 / 472, Epoch 43
# Batch 8 / 472, Epoch 43
# Batch 9 / 472, Epoch 43
# Batch 10 / 472, Epoch 43
# Batch 20 / 472, Epoch 43
# Batch 30 / 472, Epoch 43
# Batch 40 / 472, Epoch 43
# Batch 50 / 472, Epoch 43
# Batch 60 / 472, Epoch 43
# Batch 70 / 472, Epoch 43
# Batch 80 / 472, Epoch 43
# Batch 90 / 472, Epoch 43
# Batch 100 / 472, Epoch 43
# Batch 200 / 472, Epoch 43
# Batch 300 / 472, Epoch 43
# Batch 400 / 472, Epoch 43
# Epoch [43/50]
# Train Loss: 1.1496, Train Accuracy: 60.97%
# Val Loss: 1.0568, Val Accuracy: 65.55%
# --------------------------------------------------
# Batch 0 / 472, Epoch 44
# Batch 1 / 472, Epoch 44
# Batch 2 / 472, Epoch 44
# Batch 3 / 472, Epoch 44
# Batch 4 / 472, Epoch 44
# Batch 5 / 472, Epoch 44
# Batch 6 / 472, Epoch 44
# Batch 7 / 472, Epoch 44
# Batch 8 / 472, Epoch 44
# Batch 9 / 472, Epoch 44
# Batch 10 / 472, Epoch 44
# Batch 20 / 472, Epoch 44
# Batch 30 / 472, Epoch 44
# Batch 40 / 472, Epoch 44
# Batch 50 / 472, Epoch 44
# Batch 60 / 472, Epoch 44
# Batch 70 / 472, Epoch 44
# Batch 80 / 472, Epoch 44
# Batch 90 / 472, Epoch 44
# Batch 100 / 472, Epoch 44
# Batch 200 / 472, Epoch 44
# Batch 300 / 472, Epoch 44
# Batch 400 / 472, Epoch 44
# Epoch [44/50]
# Train Loss: 1.1271, Train Accuracy: 61.06%
# Val Loss: 1.0454, Val Accuracy: 65.55%
# --------------------------------------------------
# Batch 0 / 472, Epoch 45
# Batch 1 / 472, Epoch 45
# Batch 2 / 472, Epoch 45
# Batch 3 / 472, Epoch 45
# Batch 4 / 472, Epoch 45
# Batch 5 / 472, Epoch 45
# Batch 6 / 472, Epoch 45
# Batch 7 / 472, Epoch 45
# Batch 8 / 472, Epoch 45
# Batch 9 / 472, Epoch 45
# Batch 10 / 472, Epoch 45
# Batch 20 / 472, Epoch 45
# Batch 30 / 472, Epoch 45
# Batch 40 / 472, Epoch 45
# Batch 50 / 472, Epoch 45
# Batch 60 / 472, Epoch 45
# Batch 70 / 472, Epoch 45
# Batch 80 / 472, Epoch 45
# Batch 90 / 472, Epoch 45
# Batch 100 / 472, Epoch 45
# Batch 200 / 472, Epoch 45
# Batch 300 / 472, Epoch 45
# Batch 400 / 472, Epoch 45
# Epoch [45/50]
# Train Loss: 1.1093, Train Accuracy: 61.91%
# Val Loss: 1.0290, Val Accuracy: 66.67%
# --------------------------------------------------
# Batch 0 / 472, Epoch 46
# Batch 1 / 472, Epoch 46
# Batch 2 / 472, Epoch 46
# Batch 3 / 472, Epoch 46
# Batch 4 / 472, Epoch 46
# Batch 5 / 472, Epoch 46
# Batch 6 / 472, Epoch 46
# Batch 7 / 472, Epoch 46
# Batch 8 / 472, Epoch 46
# Batch 9 / 472, Epoch 46
# Batch 10 / 472, Epoch 46
# Batch 20 / 472, Epoch 46
# Batch 30 / 472, Epoch 46
# Batch 40 / 472, Epoch 46
# Batch 50 / 472, Epoch 46
# Batch 60 / 472, Epoch 46
# Batch 70 / 472, Epoch 46
# Batch 80 / 472, Epoch 46
# Batch 90 / 472, Epoch 46
# Batch 100 / 472, Epoch 46
# Batch 200 / 472, Epoch 46
# Batch 300 / 472, Epoch 46
# Batch 400 / 472, Epoch 46
# Epoch [46/50]
# Train Loss: 1.0951, Train Accuracy: 62.24%
# Val Loss: 1.0346, Val Accuracy: 66.56%
# --------------------------------------------------
# Batch 0 / 472, Epoch 47
# Batch 1 / 472, Epoch 47
# Batch 2 / 472, Epoch 47
# Batch 3 / 472, Epoch 47
# Batch 4 / 472, Epoch 47
# Batch 5 / 472, Epoch 47
# Batch 6 / 472, Epoch 47
# Batch 7 / 472, Epoch 47
# Batch 8 / 472, Epoch 47
# Batch 9 / 472, Epoch 47
# Batch 10 / 472, Epoch 47
# Batch 20 / 472, Epoch 47
# Batch 30 / 472, Epoch 47
# Batch 40 / 472, Epoch 47
# Batch 50 / 472, Epoch 47
# Batch 60 / 472, Epoch 47
# Batch 70 / 472, Epoch 47
# Batch 80 / 472, Epoch 47
# Batch 90 / 472, Epoch 47
# Batch 100 / 472, Epoch 47
# Batch 200 / 472, Epoch 47
# Batch 300 / 472, Epoch 47
# Batch 400 / 472, Epoch 47
# Epoch [47/50]
# Train Loss: 1.0879, Train Accuracy: 62.70%
# Val Loss: 1.0279, Val Accuracy: 67.09%
# --------------------------------------------------
# Batch 0 / 472, Epoch 48
# Batch 1 / 472, Epoch 48
# Batch 2 / 472, Epoch 48
# Batch 3 / 472, Epoch 48
# Batch 4 / 472, Epoch 48
# Batch 5 / 472, Epoch 48
# Batch 6 / 472, Epoch 48
# Batch 7 / 472, Epoch 48
# Batch 8 / 472, Epoch 48
# Batch 9 / 472, Epoch 48
# Batch 10 / 472, Epoch 48
# Batch 20 / 472, Epoch 48
# Batch 30 / 472, Epoch 48
# Batch 40 / 472, Epoch 48
# Batch 50 / 472, Epoch 48
# Batch 60 / 472, Epoch 48
# Batch 70 / 472, Epoch 48
# Batch 80 / 472, Epoch 48
# Batch 90 / 472, Epoch 48
# Batch 100 / 472, Epoch 48
# Batch 200 / 472, Epoch 48
# Batch 300 / 472, Epoch 48
# Batch 400 / 472, Epoch 48
# Epoch [48/50]
# Train Loss: 1.0873, Train Accuracy: 62.43%
# Val Loss: 1.0312, Val Accuracy: 66.72%
# --------------------------------------------------
# Batch 0 / 472, Epoch 49
# Batch 1 / 472, Epoch 49
# Batch 2 / 472, Epoch 49
# Batch 3 / 472, Epoch 49
# Batch 4 / 472, Epoch 49
# Batch 5 / 472, Epoch 49
# Batch 6 / 472, Epoch 49
# Batch 7 / 472, Epoch 49
# Batch 8 / 472, Epoch 49
# Batch 9 / 472, Epoch 49
# Batch 10 / 472, Epoch 49
# Batch 20 / 472, Epoch 49
# Batch 30 / 472, Epoch 49
# Batch 40 / 472, Epoch 49
# Batch 50 / 472, Epoch 49
# Batch 60 / 472, Epoch 49
# Batch 70 / 472, Epoch 49
# Batch 80 / 472, Epoch 49
# Batch 90 / 472, Epoch 49
# Batch 100 / 472, Epoch 49
# Batch 200 / 472, Epoch 49
# Batch 300 / 472, Epoch 49
# Batch 400 / 472, Epoch 49
# Epoch [49/50]
# Train Loss: 1.0895, Train Accuracy: 62.53%
# Val Loss: 1.0288, Val Accuracy: 67.20%
# --------------------------------------------------
# Batch 0 / 472, Epoch 50
# Batch 1 / 472, Epoch 50
# Batch 2 / 472, Epoch 50
# Batch 3 / 472, Epoch 50
# Batch 4 / 472, Epoch 50
# Batch 5 / 472, Epoch 50
# Batch 6 / 472, Epoch 50
# Batch 7 / 472, Epoch 50
# Batch 8 / 472, Epoch 50
# Batch 9 / 472, Epoch 50
# Batch 10 / 472, Epoch 50
# Batch 20 / 472, Epoch 50
# Batch 30 / 472, Epoch 50
# Batch 40 / 472, Epoch 50
# Batch 50 / 472, Epoch 50
# Batch 60 / 472, Epoch 50
# Batch 70 / 472, Epoch 50
# Batch 80 / 472, Epoch 50
# Batch 90 / 472, Epoch 50
# Batch 100 / 472, Epoch 50
# Batch 200 / 472, Epoch 50
# Batch 300 / 472, Epoch 50
# Batch 400 / 472, Epoch 50
# Epoch [50/50]
# Train Loss: 1.0777, Train Accuracy: 63.00%
# Val Loss: 1.0229, Val Accuracy: 66.67%
# --------------------------------------------------
# Test Loss: 0.9308, Test Accuracy: 67.99%

# %% [markdown]
# # Model Analysis

# %%
# Initialize the model and load trained weights (if available)
num_classes = len(full_dataset.classes)
model = CardAttributeCNN(num_classes).to(device)
model_path = 'base_model_v4.pth'  # Adjust to your saved model path
if os.path.exists(model_path):
    model.load_state_dict(torch.load(model_path))
    print(f"Loaded trained model from {model_path}")
model.eval()  # Set to evaluation mode

# Select a sample image (e.g., first image from the dataset)
sample_image, sample_label = full_dataset[np.random.randint(0, len(full_dataset))]  # You can change the index
sample_image = sample_image.unsqueeze(0).to(device)  # Add batch dimension

# Reverse normalization for visualizing the input image
unnorm_transform = transforms.Normalize(
    mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
    std=[1/0.229, 1/0.224, 1/0.225]
)
input_img = unnorm_transform(sample_image.squeeze(0).cpu()).permute(1, 2, 0).numpy()
input_img = input_img.clip(0, 1)

# Forward pass to get activations
with torch.no_grad():
    _, activations = model(sample_image, return_activations=True)

# Function to visualize feature maps
def visualize_feature_maps(activations, layer_names, num_channels_to_show=8):
    for layer_idx, (activation, layer_name) in enumerate(zip(activations, layer_names)):
        activation = activation.squeeze(0).cpu().numpy()  # Remove batch dimension, move to CPU
        num_channels = activation.shape[0]  # Number of channels in this layer
        channels_to_show = min(num_channels, num_channels_to_show)  # Limit to num_channels_to_show
        
        # Create a grid of subplots for this layer
        fig, axes = plt.subplots(1, channels_to_show, figsize=(channels_to_show * 2, 2))
        if channels_to_show == 1:
            axes = [axes]  # Ensure axes is iterable if only one channel
        
        for ch in range(channels_to_show):
            # Plot the feature map for this channel
            axes[ch].imshow(activation[ch], cmap='viridis')  # Use 'viridis' or 'gray' colormap
            axes[ch].axis('off')
            if ch == 0:
                axes[ch].set_title(f'{layer_name}\nChannel {ch}')
            else:
                axes[ch].set_title(f'Channel {ch}')
        plt.suptitle(f'Feature Maps for {layer_name} (First {channels_to_show} Channels)')
        plt.tight_layout()
        plt.show()

# Visualize the input image
plt.figure(figsize=(5, 5))
plt.imshow(input_img)
plt.title(f'Input Image (Class: {full_dataset.classes[sample_label]})')
plt.axis('off')
plt.show()

# Visualize feature maps for each ConvBlock
layer_names = ['Block 1 (16 channels)', 'Block 2 (32 channels)', 'Block 3 (64 channels)']
visualize_feature_maps(activations, layer_names, num_channels_to_show=8)
# Out:
# Loaded trained model from base_model_v4.pth
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 12
#      10 # Select a sample image (e.g., first image from the dataset)
#      11 sample_image, sample_label = full_dataset[np.random.randint(0, len(full_dataset))]  # You can change the index
# ---> 12 sample_image = sample_image.unsqueeze(0).to(device)  # Add batch dimension
#      14 # Reverse normalization for visualizing the input image
#      15 unnorm_transform = transforms.Normalize(
#      16     mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225],
#      17     std=[1/0.229, 1/0.224, 1/0.225]
#      18 )
#
# AttributeError: 'Image' object has no attribute 'unsqueeze'

# %% [markdown]
# 1. BATCH NORM
# 2. Use GenAI to give more transformations to the images to enrich the dataset
# 3. Can use Hugging Face pytorch-image-model (TIM)
